# %% [markdown]
# # Get Hypernyms in the definitions

# %%
import pandas as pd
import os
import pickle
## PICKLE Variables
import pickle

def pkl_vars(varname, filename):
    with open(filename, 'wb') as file:
        pickle.dump(varname, file)
def reload_vars(filename):
    this_var = None
    with open(filename, 'rb') as file:
        this_var = pickle.load(file)

# %% [markdown]
# ##  Can [WCL classifier](http://lcl.uniroma1.it/wcl/) extract hypernyms of mathematical definienda ? Very rare!
#
# Import [10_ExtractHypernyms/pom.xml](10_ExtractHypernyms/pom.xml) and run maven install to get the *+hyper.csv files
# Then import /export the csv with google sheet if pandas cannot parse them.

# %%
#df_arxiv_duplicated_term = pd.read_csv("duplicated_term_def.csv")
#df_arxiv_duplicated_term = df_arxiv_duplicated_term[~df_arxiv_duplicated_term["plain_text_def"].isnull()]
#df_arxiv_duplicated_term
# Out:
#                                                  term
# 0                                   $(C,\alpha)$-rich  \
# 1                                   $(C,\alpha)$-rich
# 2                                    $(R,c)$-expander
# 3                                    $(R,c)$-expander
# 4                                    $(R,c)$-expander
# ...                                               ...
# 3119  {{\it Lagrangian plane of pants decomposition}}
# 3120    {{\it Lagrangian planes in general position}}
# 3121    {{\it Lagrangian planes in general position}}
# 3122                      {{\it Pants decomposition}}
# 3123                      {{\it Pants decomposition}}
#
#                                                     def
# 0     [$(C,\alpha)$-rich in copies of $Z_\ell^{r,t}$...  \
# 1     [Definition~21 of~\cite{ChromThresh}, $(C,\alp...
# 2     Let $G=(V,E)$ be a graph with $|V|=n$. Let $R:...
# 3     For every $c>0$ and every positive integer $R$...
# 4     For every $c>0$ and every positive integer $R$...
# ...                                                 ...
# 3119  Let $P=\{ c_1,\dots,c_{3g-3}\}$ be a pants dec...
# 3120  Two {\it  Lagrangian planes $\L_1$ and $\L_2$ ...
# 3121  Two  Lagrangian planes $\L(P_1)$ and $\L(P_2)$...
# 3122  A {\it pants decomposition} of $S$ is a set of...
# 3123  A {\it pants decomposition} $P$ of $S$ is a sy...
#
#                              file_name       extraction_rule
# 0     1108.1746#ChromaticThreshold.tex  definition + \emph{}  \
# 1              1508.03870#RCTdense.tex  definition + \emph{}
# 2              1203.3444#1203.3444.tex  definition + \emph{}
# 3              1210.7618#1210.7618.tex  definition + \emph{}
# 4                1508.07355#trace2.tex  definition + \emph{}
# ...                                ...                   ...
# 3119           1005.0073#pants-new.tex          definition[]
# 3120           1005.0073#pants-new.tex          definition[]
# 3121            1102.4861#length12.tex          definition[]
# 3122            1102.4861#length12.tex          definition[]
# 3123           1005.0073#pants-new.tex          definition[]
#
#                                          plain_text_def
# 0     [(C,α)-rich in copies of Z_ℓ^r,t]\nLet X and Y...  \
# 1     [Definition 21 of <cit.>, (C,α)-rich in copies...
# 2     Let G=(V,E) be a graph with |V|=n. Let R:=R(n)...
# 3     For every c>0 and every positive integer R we ...
# 4     For every c>0 and every positive integer R we ...
# ...                                                 ...
# 3119  Let P={ c_1,…,c_3g-3} be a pants decomposition...
# 3120  Two Lagrangian planes Ł_1 and Ł_2  are in gene...
# 3121  Two  Lagrangian planes Ł(P_1) and Ł(P_2)  are ...
# 3122  A pants decomposition of S is a set of (non-or...
# 3123  A pants decomposition P of S is a system of no...
#
#                               plain_text_term
# 0                                  (C,α)-rich
# 1                                  (C,α)-rich
# 2                              (R,c)-expander
# 3                              (R,c)-expander
# 4                              (R,c)-expander
# ...                                       ...
# 3119  Lagrangian plane of pants decomposition
# 3120    Lagrangian planes in general position
# 3121    Lagrangian planes in general position
# 3122                      Pants decomposition
# 3123                      Pants decomposition
#
# [3124 rows x 6 columns]

# %%
#df_arxiv_duplicated_term.to_csv("10_ExtractHypernyms/duplicated_term_def_for_opencsv.csv", index=False, columns=['file_name','extraction_rule','plain_text_def','plain_text_term'])

# %%
df_arxiv_hyper = pd.read_csv("10_ExtractHypernyms/arXiv_duplicated_term_def+WCLhypernym.csv")
df_arxiv_hyper = df_arxiv_hyper[~df_arxiv_hyper['IS_DEFINITION'].isnull()]
df_arxiv_hyper.count()
# Out:
# EXTRACTION_RULE    3097
# FILE_NAME          3097
# HYPERNYM             76
# IS_DEFINITION      3097
# PLAIN_TEXT_DEF     3097
# PLAIN_TEXT_TERM    3096
# dtype: int64

# %%
df_arxiv_hyper['PLAIN_TEXT_TERM'].value_counts()
# Out:
# PLAIN_TEXT_TERM
# equivalent                                  32
# weight                                      20
# admissible                                  19
# balanced                                    18
# minimal                                     18
#                                             ..
# curvature-dimension inequality               2
# cut-equivalent                               2
# cycle                                        2
# cyclic coloring complex                      2
# Template and entropy relative to a graph     1
# Name: count, Length: 1079, dtype: int64

# %%
df_arxiv_hyper[True == df_arxiv_hyper['IS_DEFINITION']]
# Out:
#             EXTRACTION_RULE                           FILE_NAME   HYPERNYM
# 52    definition + textit{}         0901.3565#JM_partitions.tex  partition  \
# 53    definition + textit{}             0712.2075#0712.2075.tex  partition
# 54    definition + textit{}          0906.1559#dissertation.tex  partition
# 115     definition + emph{}            1005.3759#positivity.tex       pair
# 273     definition + emph{}                  1107.0090#degs.tex      Schur
# ...                     ...                                 ...        ...
# 2767           definition[]            1712.05859#bend2tree.tex      graph
# 2776  definition + textit{}             1310.1281#1310.1281.tex       game
# 2777  definition + textit{}             1310.1327#1310.1327.tex       game
# 2792    definition + emph{}                   1109.5296#Dic.tex        map
# 2986    definition + emph{}  1910.00670#ForceyRoncoSept2019.tex      nodes
#
#      IS_DEFINITION                                     PLAIN_TEXT_DEF
# 52            True  \nAn ℓ-partition is an ℓ-regular partition wit...  \
# 53            True  \nAn ℓ-partition is an ℓ-regular partition whi...
# 54            True  \nAn ℓ-partition is an ℓ-regular partition whi...
# 115           True  A k-ribbon word is a pair (w,c) consisting of ...
# 273           True  A D graph is a locally Schur positive graph sa...
# ...            ...                                                ...
# 2767          True  \nA straight linear 2-tree is a graph G_n with...
# 2776          True  A strong placement game is a combinatorial gam...
# 2777          True  \nA strong placement game is a combinatorial g...
# 2792          True  A substitution is a map from  to . If σ is a s...
# 2986          True   A tube is a set of nodes of  whose induced gr...
#
#              PLAIN_TEXT_TERM
# 52               ℓ-partition
# 53               ℓ-partition
# 54               ℓ-partition
# 115            k-ribbon word
# 273                  D graph
# ...                      ...
# 2767  straight linear 2-tree
# 2776   strong placement game
# 2777   strong placement game
# 2792            substitution
# 2986                    tube
#
# [76 rows x 6 columns]

# %%
df_proofwiki_hyper = pd.read_csv("10_ExtractHypernyms/proofwiki_disambiguation_def+WCLhypernym.csv")
df_proofwiki_hyper = df_proofwiki_hyper[~df_proofwiki_hyper['IS_DEFINITION'].isnull()]
df_proofwiki_hyper.count()
# Out:
# CATEGORIES               1415
# DD_PAGE_TITLE            1415
# DEFINITION               1415
# DEF_PAGE_TITLE           1415
# HYPERNYM                   54
# IS_DEFINITION            1415
# PLAIN_TEXT_DEFINITION    1415
# TERM                     1415
# dtype: int64

# %%
df_proofwiki_hyper[['DEF_PAGE_TITLE']].value_counts()
# Out:
# DEF_PAGE_TITLE
# Definition:Set Equivalence                             3
# Definition:Transversal (Geometry)/Interior Angle       2
# Definition:Congruence Relation                         2
# Definition:Polygon/External Angle                      2
# Definition:Arithmetic Mean                             2
#                                                       ..
# Definition:Family of Curves/One-Parameter/Parameter    1
# Definition:Factorial Number System                     1
# Definition:Exterior Derivative                         1
# Definition:Extension of Structure                      1
# Definition:Zonal Harmonic                              1
# Name: count, Length: 1349, dtype: int64

# %%
df_proofwiki_hyper[['DEF_PAGE_TITLE','CATEGORIES']].value_counts()
# Out:
# DEF_PAGE_TITLE                                       CATEGORIES
# Definition:Set Equivalence                           ['Definitions/Set Equivalence', 'Definitions/Set Theory']                                                                              3
# Definition:Transversal (Geometry)/Interior Angle     ['Definitions/Transversals (Geometry)']                                                                                                2
# Definition:Congruence Relation                       ['Definitions/Abstract Algebra', 'Definitions/Equivalence Relations']                                                                  2
# Definition:Polygon/External Angle                    ['Definitions/External Angles', 'Definitions/Polygons']                                                                                2
# Definition:Arithmetic Mean                           ['Definitions/Arithmetic Mean', 'Definitions/Pythagorean Means', 'Definitions/Algebra', 'Definitions/Measures of Central Tendency']    2
#                                                                                                                                                                                            ..
# Definition:Family of Curves/One-Parameter/Parameter  ['Definitions/One-Parameter Families of Curves', 'Definitions/One-Parameter Families']                                                 1
# Definition:Factorial Number System                   ['Definitions/Number Bases']                                                                                                           1
# Definition:Exterior Derivative                       ['Definitions/Differential Forms']                                                                                                     1
# Definition:Extension of Structure                    ['Definitions/Model Theory for Predicate Logic']                                                                                       1
# Definition:Zonal Harmonic                            ['Definitions/Zonal Harmonics', 'Definitions/Spherical Harmonics']                                                                     1
# Name: count, Length: 1349, dtype: int64

# %%
df_proofwiki_hyper[['DEF_PAGE_TITLE','TERM']].value_counts()
# Out:
# DEF_PAGE_TITLE                                                         TERM
# Definition:Above (Number)                                              Above                   1
# Definition:Orientation of Coordinate Axes/Cartesian Plane/Left-Handed  Left                    1
# Definition:Polyhedron/Adjacent/Edge to Edge                            Coterminal              1
# Definition:Polyhedron/Adjacent                                         Adjacent                1
# Definition:Polyhedral Angle/Face                                       Face                    1
#                                                                                               ..
# Definition:Expansion of Topology                                       Expansion               1
# Definition:Evaluation Linear Transformation/Module Theory              Transformation          1
# Definition:Euler Characteristic of Surface                             Euler Characteristic    1
# Definition:Euler Characteristic of Finite Graph                        Euler Characteristic    1
# Definition:Zonal Harmonic                                              Harmonic                1
# Name: count, Length: 1415, dtype: int64

# %%
df_proofwiki_hyper[True == df_proofwiki_hyper['IS_DEFINITION']]
# Out:
#                                              CATEGORIES
# 11    ['Definitions/Absolute Geometry', 'Definitions...  \
# 13                          ['Definitions/Temperature']
# 63              ['Definitions/Branches of Mathematics']
# 68    ['Definitions/Branches of Mathematics', 'Defin...
# 69    ['Definitions/Algebraic Geometry', 'Definition...
# 81    ['Definitions/Alternants', 'Definitions/Linear...
# 114   ['Definitions/Atoms', 'Definitions/Atomic Phys...
# 118   ['Definitions/Bar', 'Definitions/Units of Meas...
# 119                   ['Definitions/Ideals in Physics']
# 136   ['Definitions/Binomials (Algebra)', 'Definitio...
# 163   ['Definitions/Bridge (Game)', 'Definitions/Exa...
# 171                   ['Definitions/Ideals in Physics']
# 192   ['Definitions/Circuits (Graph Theory)', 'Defin...
# 197   ['Definitions/Branches of Mathematics', 'Defin...
# 235   ['Definitions/Branches of Mathematics', 'Defin...
# 286                               ['Definitions/Cones']
# 307                         ['Definitions/Game Theory']
# 308                         ['Definitions/Game Theory']
# 314   ['Definitions/Continuous Geometry', 'Definitio...
# 330   ['Definitions/Coterminal Angles', 'Definitions...
# 338   ['Definitions/Critical Points (Analysis)', 'De...
# 368                           ['Definitions/Monomials']
# 373   ['Definitions/Degrees of Arc', 'Definitions/Ar...
# 374                      ['Definitions/Quadrilaterals']
# 375                        ['Definitions/Hypocycloids']
# 386   ['Definitions/Diagrams', 'Definitions/Proof Te...
# 401   ['Definitions/Dihedrals (Geometry)', 'Definiti...
# 425   ['Definitions/Branches of Mathematics', 'Defin...
# 430   ['Definitions/Branches of Mathematics', 'Defin...
# 496   ['Definitions/Physics', 'Definitions/Physical ...
# 497   ['Definitions/Geometry', 'Definitions/Circles'...
# 516   ['Definitions/Euclidean Geometry', 'Definition...
# 578   ['Definitions/Frequency Curves (Statistics)', ...
# 579   ['Definitions/Frequency Curves (Probability Th...
# 617   ['Definitions/Harmonic Analysis', 'Definitions...
# 620   ['Definitions/Harmonics (Analysis)', "Definiti...
# 633                           ['Definitions/Triangles']
# 634                            ['Definitions/Polygons']
# 660   ['Definitions/Identities (Equations)', 'Defini...
# 673   ['Definitions/Inertia (Physics)', 'Definitions...
# 718                             ['Definitions/Physics']
# 730   ['Definitions/Knot (Unit of Measurement)', 'De...
# 779   ['Definitions/Length', 'Definitions/Geometry',...
# 781                   ['Definitions/Analytic Geometry']
# 797                ['Definitions/Language Definitions']
# 805   ['Definitions/Linear Algebra', 'Definitions/Al...
# 849                        ['Definitions/Solar System']
# 921   ['Definitions/Order of Derivative', 'Definitio...
# 982   ['Definitions/Principal (Economics)', 'Definit...
# 1150                            ['Definitions/Numbers']
# 1154                          ['Definitions/Triangles']
# 1196  ['Definitions/Sound', 'Definitions/Acoustics',...
# 1247  ['Definitions/Systems (Electronics)', 'Definit...
# 1409               ['Definitions/Language Definitions']
#
#                        DD_PAGE_TITLE
# 11               Definition:Absolute  \
# 13               Definition:Absolute
# 63                Definition:Algebra
# 68              Definition:Algebraic
# 69              Definition:Algebraic
# 81              Definition:Alternant
# 114                  Definition:Atom
# 118                   Definition:Bar
# 119                   Definition:Bar
# 136              Definition:Binomial
# 163                Definition:Bridge
# 171                 Definition:Chain
# 192               Definition:Circuit
# 197                 Definition:Class
# 235   Definition:Commutative Algebra
# 286                  Definition:Cone
# 307           Definition:Consequence
# 308           Definition:Consequence
# 314            Definition:Continuous
# 330            Definition:Coterminal
# 338        Definition:Critical Point
# 368                Definition:Degree
# 373                Definition:Degree
# 374               Definition:Deltoid
# 375               Definition:Deltoid
# 386               Definition:Diagram
# 401              Definition:Dihedral
# 425              Definition:Discrete
# 430              Definition:Discrete
# 496               Definition:Entropy
# 497              Definition:Epicycle
# 516             Definition:Euclidean
# 578       Definition:Frequency Curve
# 579       Definition:Frequency Curve
# 617              Definition:Harmonic
# 620              Definition:Harmonic
# 633                Definition:Height
# 634                Definition:Height
# 660              Definition:Identity
# 673               Definition:Inertia
# 718              Definition:Isotropy
# 730                  Definition:Knot
# 779                Definition:Length
# 781                Definition:Length
# 797                Definition:Letter
# 805        Definition:Linear Algebra
# 849               Definition:Mercury
# 921                 Definition:Order
# 982             Definition:Principal
# 1150                 Definition:Sign
# 1154              Definition:Similar
# 1196                Definition:Sound
# 1247               Definition:System
# 1409                 Definition:Word
#
#                                              DEFINITION
# 11    Absolute geometry is the study of Euclidean ge...  \
# 13    Absolute temperature is a measure of the amoun...
# 63    Algebra is the branch of mathematics which stu...
# 68    Algebraic topology is a branch of topology whi...
# 69    Algebraic geometry is the branch of geometry w...
# 81    An alternant is a determinant of order $n$ suc...
# 114   An atom (in the context of physics and chemist...
# 118   The bar is a CGS unit of pressure.\n\n\nIt is ...
# 119   A bar is a straight rigid body whose length in...
# 136   A binomial is an expression which has $2$ term...
# 163   Bridge is a game for $4$ players whose mechani...
# 171   A chain is an inelastic thread whose stiffness...
# 192   A circuit is a closed trail with at least one ...
# 197   A class is a collection of all sets such that ...
# 235   Commutative algebra is the branch of abstract ...
# 286   A cone is a three-dimensional geometric figure...
# 307   A consequence is a state in a game which resul...
# 308   A consequence is a state in a game which resul...
# 314   Continuous geometry is a branch of the project...
# 330   Coterminal angles are angles which are rotatio...
# 338   A critical point is a point on a graph where t...
# 368   The degree of a monomial is defined as:\n:$ds ...
# 373   The degree (of arc) is a unit of measurement o...
# 374   A deltoid is a dart such that:\n:the $2$ sides...
# 375   A deltoid is a hypocycloid with $3$ cusps.\n\n\n:
# 386   A diagram is a graphical technique for illustr...
# 401   A dihedral is a configuration in solid geometr...
# 425   \n\nDiscrete is a word used to define an objec...
# 430   Discrete geometry is a branch of geometry that...
# 496   Entropy is a property of a thermodynamic syste...
# 497   An epicycle is the orbit described by a body m...
# 516   Euclidean geometry is the branch of geometry i...
# 578   A frequency curve is a smooth curve approximat...
# 579   A frequency curve is a curve representing a fr...
# 617   Harmonic analysis is the study of functions by...
# 620   A harmonic is a solution $phi$ to Laplace's eq...
# 633   The height of a triangle is the length of a pe...
# 634   The height of a polygon is the length of a per...
# 660   An identity is an equation which is true for a...
# 673   Inertia is the tendency of a body to maintain ...
# 718   Isotropy is a property of a physical system su...
# 730   The knot is a unit of speed which is used for ...
# 779   Length is linear measure taken in a particular...
# 781   Length is linear measure taken in a particular...
# 797   A letter is one of the symbols of the alphabet...
# 805   Linear algebra is the branch of algebra which ...
# 849   Mercury is the innermost planet of the solar s...
# 921   The order of a derivative is the number of tim...
# 982   Principal is defined as a quantity of money th...
# 1150  The sign of a number is the symbol indicating ...
# 1154  Similar triangles are triangles whose correspo...
# 1196  Sound is the vibration of an elastic medium wh...
# 1247  A system is a configuration of electrical devi...
# 1409  A word in natural language is intuitively unde...
#
#                                          DEF_PAGE_TITLE             HYPERNYM
# 11                         Definition:Absolute Geometry             geometry  \
# 13                      Definition:Temperature/Absolute              measure
# 63             Definition:Algebra (Mathematical Branch)          mathematics
# 68                        Definition:Algebraic Topology             topology
# 69                        Definition:Algebraic Geometry             geometry
# 81                Definition:Alternant (Linear Algebra)          determinant
# 114                           Definition:Atom (Physics)      piece of matter
# 118                               Definition:Bar (Unit)             CGS unit
# 119                          Definition:Bar (Mechanics)                 body
# 136                       Definition:Binomial (Algebra)           expression
# 163                            Definition:Bridge (Game)                 game
# 171                          Definition:Chain (Physics)               thread
# 192                   Definition:Circuit (Graph Theory)                trail
# 197                             Definition:Class Theory                 sets
# 235   Definition:Commutative Algebra (Mathematical B...              algebra
# 286                          Definition:Cone (Geometry)               figure
# 307                Definition:Consequence (Game Theory)                state
# 308                     Definition:Consequence Function                state
# 314                      Definition:Continuous Geometry             geometry
# 330                        Definition:Coterminal Angles               angles
# 338                Definition:Critical Point (Analysis)                point
# 368   Definition:Monomial of Free Commutative Monoid...              defined
# 373                            Definition:Degree of Arc  unit of measurement
# 374               Definition:Quadrilateral/Dart/Deltoid                 dart
# 375                    Definition:Deltoid (Hypocycloid)          hypocycloid
# 386            Definition:Diagram (Graphical Technique)            technique
# 401                      Definition:Dihedral (Geometry)        configuration
# 425                     Definition:Discrete Mathematics                 word
# 430                        Definition:Discrete Geometry             geometry
# 496                        Definition:Entropy (Physics)             property
# 497           Definition:Epicycle (Ptolemaic Astronomy)                orbit
# 516                       Definition:Euclidean Geometry             geometry
# 578             Definition:Frequency Curve (Statistics)                curve
# 579     Definition:Frequency Curve (Probability Theory)                curve
# 617                        Definition:Harmonic Analysis            functions
# 620                      Definition:Harmonic (Analysis)           solution ϕ
# 633               Definition:Triangle (Geometry)/Height               length
# 634                           Definition:Polygon/Height               length
# 660                      Definition:Identity (Equation)             equation
# 673                        Definition:Inertia (Physics)             tendency
# 718                       Definition:Isotropy (Physics)             property
# 730               Definition:Knot (Unit of Measurement)        unit of speed
# 779                    Definition:Linear Measure/Length              measure
# 781                          Definition:Length of Curve              measure
# 797                       Definition:Letter of Alphabet              symbols
# 805     Definition:Linear Algebra (Mathematical Branch)              algebra
# 849                         Definition:Mercury (Planet)     innermost planet
# 921   Definition:Derivative/Higher Derivatives/Order...               number
# 982                    Definition:Principal (Economics)             quantity
# 1150                          Definition:Sign of Number               symbol
# 1154                       Definition:Similar Triangles            triangles
# 1196                         Definition:Sound (Physics)            vibration
# 1247                    Definition:System (Electronics)        configuration
# 1409                 Definition:Word (Natural Language)           understood
#
#      IS_DEFINITION                              PLAIN_TEXT_DEFINITION
# 11            True  Absolute geometry is the study of Euclidean ge...  \
# 13            True  Absolute temperature is a measure of the amoun...
# 63            True  Algebra is the branch of mathematics which stu...
# 68            True  Algebraic topology is a branch of topology whi...
# 69            True  Algebraic geometry is the branch of geometry w...
# 81            True  An alternant is a determinant of order n such ...
# 114           True  An atom (in the context of physics and chemist...
# 118           True  The bar is a CGS unit of pressure.\n\n\nIt is ...
# 119           True  A bar is a straight rigid body whose length in...
# 136           True   A binomial is an expression which has 2 terms.\n
# 163           True  Bridge is a game for 4 players whose mechanism...
# 171           True  A chain is an inelastic thread whose stiffness...
# 192           True  A circuit is a closed trail with at least one ...
# 197           True  A class is a collection of all sets such that ...
# 235           True  Commutative algebra is the branch of abstract ...
# 286           True  A cone is a three-dimensional geometric figure...
# 307           True  A consequence is a state in a game which resul...
# 308           True  A consequence is a state in a game which resul...
# 314           True  Continuous geometry is a branch of the project...
# 330           True  Coterminal angles are angles which are rotatio...
# 338           True  A critical point is a point on a graph where t...
# 368           True  The degree of a monomial is defined as:\n:∑_j ...
# 373           True  The degree (of arc) is a unit of measurement o...
# 374           True  A deltoid is a dart such that:\n:the 2 sides w...
# 375           True    A deltoid is a hypocycloid with 3 cusps.\n\n\n:
# 386           True  A diagram is a graphical technique for illustr...
# 401           True  A dihedral is a configuration in solid geometr...
# 425           True  \n\nDiscrete is a word used to define an objec...
# 430           True  Discrete geometry is a branch of geometry that...
# 496           True  Entropy is a property of a thermodynamic syste...
# 497           True  An epicycle is the orbit described by a body m...
# 516           True  Euclidean geometry is the branch of geometry i...
# 578           True  A frequency curve is a smooth curve approximat...
# 579           True  A frequency curve is a curve representing a fr...
# 617           True  Harmonic analysis is the study of functions by...
# 620           True  A harmonic is a solution ϕ to Laplace's equati...
# 633           True  The height of a triangle is the length of a pe...
# 634           True  The height of a polygon is the length of a per...
# 660           True  An identity is an equation which is true for a...
# 673           True  Inertia is the tendency of a body to maintain ...
# 718           True  Isotropy is a property of a physical system su...
# 730           True  The knot is a unit of speed which is used for ...
# 779           True  Length is linear measure taken in a particular...
# 781           True  Length is linear measure taken in a particular...
# 797           True  A letter is one of the symbols of the alphabet...
# 805           True  Linear algebra is the branch of algebra which ...
# 849           True  Mercury is the innermost planet of the solar s...
# 921           True  The order of a derivative is the number of tim...
# 982           True  Principal is defined as a quantity of money th...
# 1150          True  The sign of a number is the symbol indicating ...
# 1154          True  Similar triangles are triangles whose correspo...
# 1196          True  Sound is the vibration of an elastic medium wh...
# 1247          True  A system is a configuration of electrical devi...
# 1409          True  A word in natural language is intuitively unde...
#
#                      TERM
# 11               Absolute
# 13               Absolute
# 63                Algebra
# 68              Algebraic
# 69              Algebraic
# 81              Alternant
# 114                  Atom
# 118                   Bar
# 119                   Bar
# 136              Binomial
# 163                Bridge
# 171                 Chain
# 192               Circuit
# 197                 Class
# 235   Commutative Algebra
# 286                  Cone
# 307           Consequence
# 308           Consequence
# 314            Continuous
# 330            Coterminal
# 338        Critical Point
# 368                Degree
# 373                Degree
# 374               Deltoid
# 375               Deltoid
# 386               Diagram
# 401              Dihedral
# 425              Discrete
# 430              Discrete
# 496               Entropy
# 497              Epicycle
# 516             Euclidean
# 578       Frequency Curve
# 579       Frequency Curve
# 617              Harmonic
# 620              Harmonic
# 633                Height
# 634                Height
# 660              Identity
# 673               Inertia
# 718              Isotropy
# 730                  Knot
# 779                Length
# 781                Length
# 797                Letter
# 805        Linear Algebra
# 849               Mercury
# 921                 Order
# 982             Principal
# 1150                 Sign
# 1154              Similar
# 1196                Sound
# 1247               System
# 1409                 Word

# %% [markdown]
# We can see that when the defininiendum is a clause, the definition might not have a hypernyme, e.g.: https://proofwiki.org/wiki/Definition:Above_(Plane_Geometry)

# %%
df_proofwiki_hyper[False == df_proofwiki_hyper['IS_DEFINITION']]
# Out:
#                                              CATEGORIES
# 0                  ['Definitions/Language Definitions']  \
# 1     ['Definitions/Language Definitions', 'Definiti...
# 2     ['Definitions/Language Definitions', 'Definiti...
# 3        ['Definitions/Algebra', 'Definitions/Numbers']
# 4      ['Definitions/Constants', 'Definitions/Algebra']
# ...                                                 ...
# 1416  ['Definitions/Abstract Algebra', 'Definitions/...
# 1417                        ['Definitions/Ring Theory']
# 1418                       ['Definitions/Field Theory']
# 1419  ['Definitions/Roots of Mappings', 'Definitions...
# 1420                 ['Definitions/Algebraic Geometry']
#
#               DD_PAGE_TITLE
# 0          Definition:Above  \
# 1          Definition:Above
# 2          Definition:Above
# 3       Definition:Absolute
# 4       Definition:Absolute
# ...                     ...
# 1416        Definition:Zero
# 1417        Definition:Zero
# 1418        Definition:Zero
# 1419        Definition:Zero
# 1420  Definition:Zero Locus
#
#                                              DEFINITION
# 0     In the context of numbers, above means greater...  \
# 1     Let $a$ and $b$ be points in $3$-dimensional E...
# 2     Let $a$ and $b$ be points in the cartesian pla...
# 3     An absolute number is a number in an expressio...
# 4     A constant is a name for an object (usually a ...
# ...                                                 ...
# 1416  Let $left( S, circ right)$ be an algebraic str...
# 1417  Let $left( R, +, circ right)$ be a ring.\n\nTh...
# 1418  Let $left( F, +, times right)$ be a field.\n\n...
# 1419  Let $f: R to R$ be a mapping on a ring $R$.\n\...
# 1420  Let $k$ be a field.\n\nLet $ngeq1$ be a natura...
#
#                                    DEF_PAGE_TITLE HYPERNYM IS_DEFINITION
# 0                       Definition:Above (Number)      NaN         False  \
# 1               Definition:Above (Solid Geometry)      NaN         False
# 2               Definition:Above (Plane Geometry)      NaN         False
# 3                      Definition:Absolute Number      NaN         False
# 4                             Definition:Constant      NaN         False
# ...                                           ...      ...           ...
# 1416                      Definition:Zero Element      NaN         False
# 1417                         Definition:Ring Zero      NaN         False
# 1418                        Definition:Field Zero      NaN         False
# 1419                   Definition:Root of Mapping      NaN         False
# 1420  Definition:Zero Locus of Set of Polynomials      NaN         False
#
#                                   PLAIN_TEXT_DEFINITION        TERM
# 0     In the context of numbers, above means greater...       Above
# 1     Let a and b be points in 3-dimensional Euclide...       Above
# 2     Let a and b be points in the cartesian plane ℝ...       Above
# 3     An absolute number is a number in an expressio...    Absolute
# 4     A constant is a name for an object (usually a ...    Absolute
# ...                                                 ...         ...
# 1416  Let ( S, ∘) be an algebraic structure.\n\nAn e...        Zero
# 1417  Let ( R, +, ∘) be a ring.\n\nThe identity for ...        Zero
# 1418  Let ( F, +, ×) be a field.\n\nThe identity for...        Zero
# 1419  Let f: R → R be a mapping on a ring R.\n\nLet ...        Zero
# 1420  Let k be a field.\n\nLet n≥1 be a natural numb...  Zero Locus
#
# [1361 rows x 8 columns]

# %% [markdown]
# ## Rule-based Extraction

# %%
import re

# %%
def extract_definiens(definition):
    """
    Extracts the definiens from a mathematical definition using regular expressions.
    This assumes the definition follows a pattern where 'is' or similar verbs introduce the definiens.
    """
    # Regular expression to capture the definiens after phrases like "is", "are", "refers to", etc.
    definiens_pattern = r'\b(?:is|are|refers to|means|can be defined as)\b\s(.+?)\.'
    
    # Find matches
    match = re.search(definiens_pattern, definition)
    
    if match:
        return match.group(1).strip()
    else:
        return "No definiens found."

# Example usage
definition = "A circle is a shape with all points equidistant from its center."
definiens = extract_definiens(definition)
print("Extracted definiens:")
print(definiens)
# Out:
# Extracted definiens:
# a shape with all points equidistant from its center
