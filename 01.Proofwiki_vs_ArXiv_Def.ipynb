# %% [markdown]
# # Check overlaps of terms in Proofwiki and in arXiv papers

# %%
import pandas as pd
import os
import pickle
## PICKLE Variables
import pickle

def pkl_vars(varname, filename):
    with open(filename, 'wb') as file:
        pickle.dump(varname, file)
def reload_vars(filename):
    this_var = None
    with open(filename, 'rb') as file:
        this_var = pickle.load(file)

# %%
df_proofwiki_dd = pd.read_csv("parsed_disambiguation_list_without===.csv")
df_proofwiki_dd
# Out:
#               dd_page_title        term
# 0          Definition:Above       Above  \
# 1          Definition:Above       Above
# 2          Definition:Above       Above
# 3       Definition:Absolute    Absolute
# 4       Definition:Absolute    Absolute
# ...                     ...         ...
# 1976        Definition:Zero        Zero
# 1977        Definition:Zero        Zero
# 1978        Definition:Zero        Zero
# 1979  Definition:Zero Locus  Zero Locus
# 1980  Definition:Zero Locus  Zero Locus
#
#                                              definition
# 0     In the context of numbers, above means greater...  \
# 1     Let $a$ and $b$ be points in $3$-dimensional E...
# 2     Let $a$ and $b$ be points in the cartesian pla...
# 3     An absolute number is a number in an expressio...
# 4     A constant is a name for an object (usually a ...
# ...                                                 ...
# 1976  Let $\mathbb A$ be one of the standard number ...
# 1977  Let $f: R \to R$ be a mapping on a ring $R$.\n...
# 1978  Let $\left( R, +_R, \times_R \right)$ be a rin...
# 1979  Let $k$ be a field.\n\nLet $n\geq1$ be a natur...
# 1980  Let $A$ be a commutative ring with unity.\n\nL...
#
#                                    def_page_title
# 0                       Definition:Above (Number)  \
# 1               Definition:Above (Solid Geometry)
# 2               Definition:Above (Plane Geometry)
# 3                      Definition:Absolute Number
# 4                             Definition:Constant
# ...                                           ...
# 1976                      Definition:Zero Mapping
# 1977                   Definition:Root of Mapping
# 1978                       Definition:Zero Vector
# 1979  Definition:Zero Locus of Set of Polynomials
# 1980   Definition:Vanishing Set of Subset of Ring
#
#                                              categories
# 0                  ['Definitions/Language Definitions']  \
# 1     ['Definitions/Language Definitions', 'Definiti...
# 2     ['Definitions/Language Definitions', 'Definiti...
# 3        ['Definitions/Algebra', 'Definitions/Numbers']
# 4      ['Definitions/Constants', 'Definitions/Algebra']
# ...                                                 ...
# 1976                     ['Definitions/Mapping Theory']
# 1977  ['Definitions/Roots of Mappings', 'Definitions...
# 1978  ['Definitions/Module Theory', 'Definitions/Vec...
# 1979                 ['Definitions/Algebraic Geometry']
# 1980                   ['Definitions/Zariski Topology']
#
#                                   plain_text_definition
# 0     In the context of numbers, above means greater...
# 1     Let a and b be points in 3-dimensional Euclide...
# 2     Let a and b be points in the cartesian plane ℝ...
# 3     An absolute number is a number in an expressio...
# 4     A constant is a name for an object (usually a ...
# ...                                                 ...
# 1976  Let 𝔸 be one of the standard number systems ℕ,...
# 1977  Let f: R → R be a mapping on a ring R.\n\nLet ...
# 1978  Let ( R, +_R, ×_R ) be a ring.\n\nLet ( G, +_G...
# 1979  Let k be a field.\n\nLet n≥1 be a natural numb...
# 1980  Let A be a commutative ring with unity.\n\nLet...
#
# [1981 rows x 6 columns]

# %%
df_arxiv_duplicated_term = pd.read_csv("duplicated_term_def.csv")

# %%
df_arxiv_duplicated_term = df_arxiv_duplicated_term[~df_arxiv_duplicated_term["plain_text_def"].isnull()]
df_arxiv_duplicated_term
# Out:
#                                                  term
# 0                                   $(C,\alpha)$-rich  \
# 1                                   $(C,\alpha)$-rich
# 2                                    $(R,c)$-expander
# 3                                    $(R,c)$-expander
# 4                                    $(R,c)$-expander
# ...                                               ...
# 3119  {{\it Lagrangian plane of pants decomposition}}
# 3120    {{\it Lagrangian planes in general position}}
# 3121    {{\it Lagrangian planes in general position}}
# 3122                      {{\it Pants decomposition}}
# 3123                      {{\it Pants decomposition}}
#
#                                                     def
# 0     [$(C,\alpha)$-rich in copies of $Z_\ell^{r,t}$...  \
# 1     [Definition~21 of~\cite{ChromThresh}, $(C,\alp...
# 2     Let $G=(V,E)$ be a graph with $|V|=n$. Let $R:...
# 3     For every $c>0$ and every positive integer $R$...
# 4     For every $c>0$ and every positive integer $R$...
# ...                                                 ...
# 3119  Let $P=\{ c_1,\dots,c_{3g-3}\}$ be a pants dec...
# 3120  Two {\it  Lagrangian planes $\L_1$ and $\L_2$ ...
# 3121  Two  Lagrangian planes $\L(P_1)$ and $\L(P_2)$...
# 3122  A {\it pants decomposition} of $S$ is a set of...
# 3123  A {\it pants decomposition} $P$ of $S$ is a sy...
#
#                              file_name       extraction_rule
# 0     1108.1746#ChromaticThreshold.tex  definition + \emph{}  \
# 1              1508.03870#RCTdense.tex  definition + \emph{}
# 2              1203.3444#1203.3444.tex  definition + \emph{}
# 3              1210.7618#1210.7618.tex  definition + \emph{}
# 4                1508.07355#trace2.tex  definition + \emph{}
# ...                                ...                   ...
# 3119           1005.0073#pants-new.tex          definition[]
# 3120           1005.0073#pants-new.tex          definition[]
# 3121            1102.4861#length12.tex          definition[]
# 3122            1102.4861#length12.tex          definition[]
# 3123           1005.0073#pants-new.tex          definition[]
#
#                                          plain_text_def
# 0     [(C,α)-rich in copies of Z_ℓ^r,t]\nLet X and Y...  \
# 1     [Definition 21 of <cit.>, (C,α)-rich in copies...
# 2     Let G=(V,E) be a graph with |V|=n. Let R:=R(n)...
# 3     For every c>0 and every positive integer R we ...
# 4     For every c>0 and every positive integer R we ...
# ...                                                 ...
# 3119  Let P={ c_1,…,c_3g-3} be a pants decomposition...
# 3120  Two Lagrangian planes Ł_1 and Ł_2  are in gene...
# 3121  Two  Lagrangian planes Ł(P_1) and Ł(P_2)  are ...
# 3122  A pants decomposition of S is a set of (non-or...
# 3123  A pants decomposition P of S is a system of no...
#
#                               plain_text_term
# 0                                  (C,α)-rich
# 1                                  (C,α)-rich
# 2                              (R,c)-expander
# 3                              (R,c)-expander
# 4                              (R,c)-expander
# ...                                       ...
# 3119  Lagrangian plane of pants decomposition
# 3120    Lagrangian planes in general position
# 3121    Lagrangian planes in general position
# 3122                      Pants decomposition
# 3123                      Pants decomposition
#
# [3124 rows x 6 columns]

# %%
df_arxiv_duplicated_term.to_csv("duplicated_term_def_for_opencsv.csv", index=False, columns=['file_name','extraction_rule','plain_text_def','plain_text_term'])

# %% [markdown]
# ## How many terms are duplicated both in arXiv papers and in proofwiki? 99 unique values.

# %%
arxiv_duplicated_terms = [s.lower() for s in df_arxiv_duplicated_term['plain_text_term'] ]
common_def_pw = df_proofwiki_dd[ df_proofwiki_dd['term'].str.lower().isin(arxiv_duplicated_terms)]
common_def_pw
# Out:
#             dd_page_title      term
# 24     Definition:Acyclic   Acyclic  \
# 25     Definition:Acyclic   Acyclic
# 26     Definition:Acyclic   Acyclic
# 27     Definition:Acyclic   Acyclic
# 33    Definition:Adjacent  Adjacent
# ...                   ...       ...
# 1956    Definition:Weight    Weight
# 1957    Definition:Weight    Weight
# 1958    Definition:Weight    Weight
# 1959    Definition:Weight    Weight
# 1960    Definition:Weight    Weight
#
#                                              definition
# 24    Let $\mathbf A$ be an abelian category with en...  \
# 25    Let $\mathbf A$ be an abelian category with en...
# 26    An acyclic graph is a graph or digraph with no...
# 27    Let $X$ be a topological space.\n\nLet $\mathc...
# 33    === Vertices ===\n=== Undirected Graph ===\nLe...
# ...                                                 ...
# 1956  Let $N = \left( V, E, w \right)$ be a network ...
# 1957  Let $N = \left({V, E, w}\right)$ be a network....
# 1958  A weight function on a set $S$ is a mapping fr...
# 1959  Let $C$ be a codeword of a linear code.\n\nThe...
# 1960  A set of weights consists of a number of solid...
#
#                             def_page_title
# 24               Definition:Acyclic Object  \
# 25           Definition:Acyclic Resolution
# 26                Definition:Acyclic Graph
# 27                Definition:Acyclic Sheaf
# 33      Definition:Adjacent (Graph Theory)
# ...                                    ...
# 1956             Definition:Network/Weight
# 1957    Definition:Network/Weight Function
# 1958            Definition:Weight Function
# 1959  Definition:Weight of Linear Codeword
# 1960                    Definition:Weights
#
#                                              categories
# 24                  ['Definitions/Homological Algebra']  \
# 25                  ['Definitions/Homological Algebra']
# 26                         ['Definitions/Graph Theory']
# 27    ['Definitions/Homological Algebra', 'Definitio...
# 33    ['Definitions/Adjacency (Graph Theory)', 'Defi...
# ...                                                 ...
# 1956                     ['Definitions/Network Theory']
# 1957                     ['Definitions/Network Theory']
# 1958  ['Definitions/Statistics', 'Definitions/Discre...
# 1959                       ['Definitions/Linear Codes']
# 1960                   ['Definitions/Weight (Physics)']
#
#                                   plain_text_definition
# 24    Let 𝐀 be an abelian category with enough injec...
# 25    Let 𝐀 be an abelian category with enough injec...
# 26    An acyclic graph is a graph or digraph with no...
# 27    Let X be a topological space.\n\nLet ℱ be an a...
# 33    === Vertices ===\n=== Undirected Graph ===\nLe...
# ...                                                 ...
# 1956  Let N = ( V, E, w ) be a network with weight f...
# 1957  Let N = (V, E, w) be a network.\n\nThe mapping...
# 1958  A weight function on a set S is a mapping from...
# 1959  Let C be a codeword of a linear code.\n\nThe w...
# 1960  A set of weights consists of a number of solid...
#
# [730 rows x 6 columns]

# %%
common_set_pw = set(common_def_pw['term'].str.lower().to_list())
len(common_set_pw), common_set_pw
# Out:
# (99,
#  {'acyclic',
#   'adjacent',
#   'algebra',
#   'alphabet',
#   'archimedean',
#   'argument',
#   'automorphism',
#   'base',
#   'basis',
#   'boundary',
#   'bridge',
#   'canonical',
#   'chain',
#   'character',
#   'circuit',
#   'closed',
#   'closure',
#   'compact',
#   'compatible',
#   'complement',
#   'complete',
#   'completion',
#   'composition',
#   'cone',
#   'conjugate',
#   'connected',
#   'consistent',
#   'convex',
#   'cycle',
#   'cyclic',
#   'decomposition',
#   'degenerate',
#   'degree',
#   'density',
#   'diagram',
#   'diameter',
#   'dimension',
#   'distance',
#   'distributive',
#   'divisor',
#   'dual',
#   'embedding',
#   'entropy',
#   'expansion',
#   'extension',
#   'face',
#   'factor',
#   'free',
#   'generated',
#   'genus',
#   'graph',
#   'height',
#   'homogeneous',
#   'homomorphism',
#   'independent',
#   'index',
#   'intersection',
#   'inverse',
#   'irreducible',
#   'join',
#   'length',
#   'locally finite',
#   'meet',
#   'minor',
#   'monotone',
#   'multiplicity',
#   'normal',
#   'orientation',
#   'orthogonal',
#   'path',
#   'perfect',
#   'primitive',
#   'product',
#   'projection',
#   'proper',
#   'range',
#   'rank',
#   'reducible',
#   'regular',
#   'rotation',
#   'section',
#   'separable',
#   'separated',
#   'sign',
#   'signature',
#   'similar',
#   'simple',
#   'smooth',
#   'subdivision',
#   'substitution',
#   'sum',
#   'support',
#   'tensor product',
#   'transitive',
#   'tree',
#   'triangle',
#   'trivial',
#   'valid',
#   'weight'})

# %%
pw_dd_terms = [s.lower() for s in df_proofwiki_dd['term'] ]
common_def_ax = df_arxiv_duplicated_term[ df_arxiv_duplicated_term['plain_text_term'].str.lower().isin(pw_dd_terms) ]
common_def_ax
# Out:
#              term                                                def
# 165       Algebra  \label{defn:algebra}\n  A unital associative a...  \
# 166       Algebra  \label{defn:algebra}\n  A unital associative a...
# 182   Archimedean  A quadratic module $\mathrm{QM}(g_1,\dots,g_m)...
# 183   Archimedean  A quadratic module $\mathrm{QM}(g_1,\dots,g_m)...
# 279        Degree  \label{definition:degree}\nLet $|\Delta|\in\ma...
# ...           ...                                                ...
# 3077       weight  \label{def:frachomM}Let $\cL$ be a $3$-uniform...
# 3078       weight  \label{defn:partition_weight}\nThe \emph{weigh...
# 3079       weight  The \emph{weight} of a rectangle $R$ is $\wt(R...
# 3080       weight  Given a (possibly looped) graph $H$ and a func...
# 3081       weight  \label{weight}\nThe \emph{weight} $\wt(\T)$ of...
#
#                                  file_name       extraction_rule
# 165           1008.1471#Tanasa-Gherman.tex          definition[]  \
# 166             1211.4429#CKscale-long.tex          definition[]
# 182                 1408.1063#Article3.tex  definition + \emph{}
# 183                1408.1065#1408.1065.tex  definition + \emph{}
# 279    1805.00115#cross-ratio_counting.tex          definition[]
# ...                                    ...                   ...
# 3077  1603.04462#loosecyc_vertex-arxiv.tex  definition + \emph{}
# 3078                0709.3079#conifold.tex  definition + \emph{}
# 3079               1110.6645#1110.6645.tex  definition + \emph{}
# 3080               1503.00998#existhom.tex  definition + \emph{}
# 3081                   1007.5174#CSSW5.tex  definition + \emph{}
#
#                                          plain_text_def plain_text_term
# 165   \n  A unital associative algebra A over a fiel...         Algebra
# 166   \n  A unital associative algebra A over a fiel...         Algebra
# 182   A quadratic module QM(g_1,…,g_m) is Archimedea...     Archimedean
# 183   A quadratic module QM(g_1,…,g_m) is Archimedea...     Archimedean
# 279   \nLet |Δ|∈ℕ_>0. A set Δ:={ (v_i,x_i)}_i=1,…,|Δ...          Degree
# ...                                                 ...             ...
# 3077  Let  be a 3-uniform hypergraph. \nA function h...          weight
# 3078  \nThe weight of π, w_0(π), is\n\n    q_0^#{dar...          weight
# 3079  The weight of a rectangle R is (R) = 2∑_p∈ Rρ(...          weight
# 3080  Given a (possibly looped) graph H and a functi...          weight
# 3081  \nThe weight () of a staircase tableau  is a m...          weight
#
# [526 rows x 6 columns]

# %%
common_set_ax = set(common_def_ax['plain_text_term'].str.lower().to_list())
len(common_set_ax), common_set_ax
# Out:
# (99,
#  {'acyclic',
#   'adjacent',
#   'algebra',
#   'alphabet',
#   'archimedean',
#   'argument',
#   'automorphism',
#   'base',
#   'basis',
#   'boundary',
#   'bridge',
#   'canonical',
#   'chain',
#   'character',
#   'circuit',
#   'closed',
#   'closure',
#   'compact',
#   'compatible',
#   'complement',
#   'complete',
#   'completion',
#   'composition',
#   'cone',
#   'conjugate',
#   'connected',
#   'consistent',
#   'convex',
#   'cycle',
#   'cyclic',
#   'decomposition',
#   'degenerate',
#   'degree',
#   'density',
#   'diagram',
#   'diameter',
#   'dimension',
#   'distance',
#   'distributive',
#   'divisor',
#   'dual',
#   'embedding',
#   'entropy',
#   'expansion',
#   'extension',
#   'face',
#   'factor',
#   'free',
#   'generated',
#   'genus',
#   'graph',
#   'height',
#   'homogeneous',
#   'homomorphism',
#   'independent',
#   'index',
#   'intersection',
#   'inverse',
#   'irreducible',
#   'join',
#   'length',
#   'locally finite',
#   'meet',
#   'minor',
#   'monotone',
#   'multiplicity',
#   'normal',
#   'orientation',
#   'orthogonal',
#   'path',
#   'perfect',
#   'primitive',
#   'product',
#   'projection',
#   'proper',
#   'range',
#   'rank',
#   'reducible',
#   'regular',
#   'rotation',
#   'section',
#   'separable',
#   'separated',
#   'sign',
#   'signature',
#   'similar',
#   'simple',
#   'smooth',
#   'subdivision',
#   'substitution',
#   'sum',
#   'support',
#   'tensor product',
#   'transitive',
#   'tree',
#   'triangle',
#   'trivial',
#   'valid',
#   'weight'})

# %% [markdown]
# ## How many proofwiki definienda are conatiend in paper-defined definienda

# %%
len(common_def_pw['plain_text_definition'].unique())
# Out:
# 713

# %%
proofwiki_dd_terms = set(df_proofwiki_dd['term'])
searchfor_terms_str = '|'.join(set(proofwiki_dd_terms)).casefold()
mentionned_definienda = df_arxiv_duplicated_term[ df_arxiv_duplicated_term['plain_text_term'].str.contains(searchfor_terms_str, case=False) ]
len(mentionned_definienda)
# Out:
# 1530

# %%
mentioned_terms = [ [t for t in proofwiki_dd_terms if t.lower() in ptt.lower()]  for ptt in mentionned_definienda['plain_text_term']]

# %%
len(mentioned_terms), mentioned_terms
# Out:
# (1530,
#  [['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Regular'],
#   ['Regular'],
#   ['Dense'],
#   ['Dense'],
#   ['Graph'],
#   ['Graph'],
#   ['Perfect'],
#   ['Perfect'],
#   ['Top'],
#   ['Top'],
#   ['Graph'],
#   ['Graph'],
#   ['Domain'],
#   ['Domain'],
#   ['Content'],
#   ['Content'],
#   ['Regular'],
#   ['Regular'],
#   ['Regular'],
#   ['Regular'],
#   ['Regular'],
#   ['Connected'],
#   ['Connected'],
#   ['Regular'],
#   ['Regular'],
#   ['Segment'],
#   ['Segment'],
#   ['Age'],
#   ['Age'],
#   ['Graph'],
#   ['Graph'],
#   ['Entropy', 'Proper'],
#   ['Entropy', 'Proper'],
#   ['Connected'],
#   ['Connected'],
#   ['Linear Form'],
#   ['Linear Form'],
#   ['Linear Form'],
#   ['Regular'],
#   ['Regular'],
#   ['Regular'],
#   ['Regular'],
#   ['Regular'],
#   ['Word'],
#   ['Word'],
#   ['Table'],
#   ['Table'],
#   ['Sum'],
#   ['Sum'],
#   ['Dimension', 'Lattice', 'Projection'],
#   ['Dimension', 'Lattice', 'Projection'],
#   ['Table'],
#   ['Table'],
#   ['Complete', 'Regular'],
#   ['Complete', 'Regular'],
#   ['Join'],
#   ['Join'],
#   ['Left', 'Homogeneous'],
#   ['Left', 'Homogeneous'],
#   ['Cyclic', 'Acyclic', 'Orientation'],
#   ['Cyclic', 'Acyclic', 'Orientation'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Algebra'],
#   ['Algebra'],
#   ['Archimedean'],
#   ['Archimedean'],
#   ['Atom'],
#   ['Atom'],
#   ['Bar', 'Diagram'],
#   ['Bar', 'Diagram'],
#   ['System'],
#   ['System'],
#   ['Cut'],
#   ['Cut'],
#   ['Top'],
#   ['Top'],
#   ['Order'],
#   ['Order'],
#   ['Product'],
#   ['Product'],
#   ['Product'],
#   ['Product'],
#   ['Product'],
#   ['Product'],
#   ['Product'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Substitution'],
#   ['Substitution'],
#   ['Complex'],
#   ['Complex'],
#   ['Dimension'],
#   ['Dimension'],
#   ['Graph', 'Complete'],
#   ['Graph', 'Complete'],
#   ['Complete'],
#   ['Complete'],
#   ['Complex'],
#   ['Complex'],
#   ['Complex'],
#   ['Graph'],
#   ['Graph'],
#   ['Degree'],
#   ['Degree'],
#   ['Degree'],
#   ['Density'],
#   ['Density'],
#   ['Density'],
#   ['Path'],
#   ['Path'],
#   ['Distance'],
#   ['Distance'],
#   ['Embedding'],
#   ['Embedding'],
#   ['Embedding'],
#   ['Entropy'],
#   ['Entropy'],
#   ['Parameter'],
#   ['Parameter'],
#   ['Decomposition', 'Composition'],
#   ['Decomposition', 'Composition'],
#   ['Factor'],
#   ['Factor'],
#   ['Factor'],
#   ['Factor'],
#   ['Factor'],
#   ['Factor'],
#   ['Factor'],
#   ['Factor'],
#   ['Graph'],
#   ['Graph'],
#   ['Common'],
#   ['Common'],
#   ['Top'],
#   ['Top'],
#   ['Top'],
#   ['Top'],
#   ['Embedding'],
#   ['Embedding'],
#   ['Weak'],
#   ['Weak'],
#   ['Basis'],
#   ['Basis'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Product'],
#   ['Product'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Weight'],
#   ['Weight'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Algebra'],
#   ['Algebra'],
#   ['Algebra'],
#   ['Algebra'],
#   ['Algebra'],
#   ['Graph'],
#   ['Graph'],
#   ['Tree'],
#   ['Tree'],
#   ['Section', 'Graph', 'Intersection'],
#   ['Section', 'Graph', 'Intersection'],
#   ['Dimension'],
#   ['Dimension'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Limit'],
#   ['Limit'],
#   ['Limit'],
#   ['Limit'],
#   ['Limit', 'Space'],
#   ['Limit', 'Space'],
#   ['Graph'],
#   ['Graph'],
#   ['Linear Form'],
#   ['Linear Form'],
#   ['Linear Form'],
#   ['Linear Form'],
#   ['Table'],
#   ['Table'],
#   ['Word'],
#   ['Word'],
#   ['Decomposition', 'Tree', 'Composition'],
#   ['Decomposition', 'Tree', 'Composition'],
#   ['Major'],
#   ['Major'],
#   ['Minor'],
#   ['Minor'],
#   ['Meet'],
#   ['Meet'],
#   ['Torsion'],
#   ['Torsion'],
#   ['Sum'],
#   ['Sum'],
#   ['Multiplicity'],
#   ['Multiplicity'],
#   ['Top'],
#   ['Top'],
#   ['Class'],
#   ['Class'],
#   ['Order'],
#   ['Order'],
#   ['Edge', 'Vertex', 'Graph', 'Side', 'Composition'],
#   ['Edge', 'Vertex', 'Graph', 'Side', 'Composition'],
#   ['Orientation'],
#   ['Orientation'],
#   ['Orientation'],
#   ['Path'],
#   ['Path'],
#   ['Perfect'],
#   ['Perfect'],
#   ['Factor'],
#   ['Factor'],
#   ['Factor'],
#   ['Dimension'],
#   ['Dimension'],
#   ['Dimension'],
#   ['Below'],
#   ['Below'],
#   ['Class'],
#   ['Class'],
#   ['Space'],
#   ['Space'],
#   ['Rank'],
#   ['Rank'],
#   ['Rank'],
#   ['Rank'],
#   ['Rank'],
#   ['Rank'],
#   ['Rank'],
#   ['Rank'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph', 'Regular'],
#   ['Graph', 'Regular'],
#   ['Regular'],
#   ['Regular'],
#   ['Regular'],
#   ['Regular'],
#   ['Regular'],
#   ['Entropy'],
#   ['Entropy'],
#   ['Entropy'],
#   ['Root', 'Degree'],
#   ['Root', 'Degree'],
#   ['Root', 'Tree'],
#   ['Root', 'Tree'],
#   ['Diagram'],
#   ['Diagram'],
#   ['Row'],
#   ['Row'],
#   ['Factor'],
#   ['Factor'],
#   ['Simple'],
#   ['Simple'],
#   ['Strong'],
#   ['Strong'],
#   ['Regular'],
#   ['Regular'],
#   ['Regular'],
#   ['Graph', 'Entropy'],
#   ['Graph', 'Entropy'],
#   ['Graph'],
#   ['Graph'],
#   ['Word'],
#   ['Word'],
#   ['Decomposition', 'Tree', 'Composition'],
#   ['Decomposition', 'Tree', 'Composition'],
#   ['Tree'],
#   ['Tree'],
#   ['Tree'],
#   ['Tree'],
#   ['Product'],
#   ['Product'],
#   ['Edge', 'Vertex'],
#   ['Edge', 'Vertex'],
#   ['Walk'],
#   ['Walk'],
#   ['Walk', 'Weight'],
#   ['Walk', 'Weight'],
#   ['Diagram'],
#   ['Diagram'],
#   ['Diagram'],
#   ['Characteristic', 'Character', 'Weight', 'Orthogonal', 'Radius'],
#   ['Characteristic', 'Character', 'Weight', 'Orthogonal', 'Radius'],
#   ['Characteristic', 'Character', 'Weight', 'Orthogonal', 'Radius'],
#   ['Tree'],
#   ['Tree'],
#   ['Above', 'Below'],
#   ['Above', 'Below'],
#   ['Cyclic', 'Acyclic'],
#   ['Cyclic', 'Acyclic'],
#   ['Cyclic', 'Acyclic'],
#   ['Cyclic', 'Acyclic'],
#   ['Cyclic', 'Acyclic'],
#   ['Cyclic', 'Acyclic'],
#   ['Cyclic', 'Acyclic'],
#   ['Cyclic', 'Acyclic'],
#   ['Cyclic', 'Acyclic'],
#   ['Cyclic', 'Dimension', 'Acyclic'],
#   ['Cyclic', 'Dimension', 'Acyclic'],
#   ['Cyclic', 'Dimension', 'Acyclic'],
#   ['Sign'],
#   ['Sign'],
#   ['Adjacent'],
#   ['Adjacent'],
#   ['Adjacent'],
#   ['Adjacent'],
#   ['Pair'],
#   ['Pair'],
#   ['Algebra'],
#   ['Algebra'],
#   ['Alphabet'],
#   ['Alphabet'],
#   ['Cycle'],
#   ['Cycle'],
#   ['Sign'],
#   ['Sign'],
#   ['Sign'],
#   ['Sign'],
#   ['Period'],
#   ['Period'],
#   ['Word'],
#   ['Word'],
#   ['Argument'],
#   ['Argument'],
#   ['Multiplicity'],
#   ['Multiplicity'],
#   ['Automorphism'],
#   ['Automorphism'],
#   ['Automorphism'],
#   ['Automorphism'],
#   ['Automorphism'],
#   ['Automorphism'],
#   ['Base'],
#   ['Base'],
#   ['Basis'],
#   ['Basis'],
#   ['Basis'],
#   ['Tree'],
#   ['Tree'],
#   ['Tree'],
#   ['Graph'],
#   ['Graph'],
#   ['Boundary'],
#   ['Boundary'],
#   ['Boundary'],
#   ['Branch', 'Decomposition', 'Composition'],
#   ['Branch', 'Decomposition', 'Composition'],
#   ['Bridge'],
#   ['Bridge'],
#   ['Canonical'],
#   ['Canonical'],
#   ['Canonical'],
#   ['Canonical'],
#   ['Canonical'],
#   ['Canonical'],
#   ['Canonical'],
#   ['Canonical'],
#   ['Canonical'],
#   ['Product'],
#   ['Product'],
#   ['Product'],
#   ['Degree'],
#   ['Degree'],
#   ['Chain'],
#   ['Chain'],
#   ['Chain'],
#   ['Proper', 'Chain'],
#   ['Proper', 'Chain'],
#   ['Character'],
#   ['Character'],
#   ['Embedding'],
#   ['Embedding'],
#   ['Diagram'],
#   ['Diagram'],
#   ['Graph'],
#   ['Graph'],
#   ['Circuit'],
#   ['Circuit'],
#   ['Circuit'],
#   ['Circuit'],
#   ['Circuit'],
#   ['Edge', 'Graph', 'Weight'],
#   ['Edge', 'Graph', 'Weight'],
#   ['Complex'],
#   ['Complex'],
#   ['Complex'],
#   ['Closed'],
#   ['Closed'],
#   ['Closed'],
#   ['Closed'],
#   ['Closed'],
#   ['Closed'],
#   ['Closed'],
#   ['Closed'],
#   ['Closed'],
#   ['Closure'],
#   ['Closure'],
#   ['Closure'],
#   ['Closure'],
#   ['Closure'],
#   ['Closure'],
#   ['Closure'],
#   ['Closure'],
#   ['Closure'],
#   ['Closure'],
#   ['Algebra'],
#   ['Algebra'],
#   ['Algebra'],
#   ['Degree'],
#   ['Degree'],
#   ['Graph'],
#   ['Graph'],
#   ['Complex'],
#   ['Complex'],
#   ['Complex'],
#   ['Dimension'],
#   ['Dimension'],
#   ['Dimension'],
#   ['Common'],
#   ['Common'],
#   ['Compact'],
#   ['Compact'],
#   ['Compact'],
#   ['Compact'],
#   ['Compact'],
#   ['Compact'],
#   ['Compact'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Compatible'],
#   ['Complement'],
#   ['Complement'],
#   ['Complete'],
#   ['Complete'],
#   ['Complete'],
#   ['Complete'],
#   ['Complete'],
#   ['Complete'],
#   ['Complete'],
#   ['Complete'],
#   ['Complete'],
#   ['Complete'],
#   ['Complete', 'Monotone'],
#   ['Complete', 'Monotone'],
#   ['Complete'],
#   ['Complete'],
#   ['Transitive', 'Complete', 'Regular'],
#   ['Transitive', 'Complete', 'Regular'],
#   ['Completion'],
#   ['Completion'],
#   ['Complex'],
#   ['Complex'],
#   ['Complex'],
#   ['Complex'],
#   ['Component'],
#   ['Component'],
#   ['Composition'],
#   ['Composition'],
#   ['Composition'],
#   ['Composition'],
#   ['Composition'],
#   ['Composition'],
#   ['Composition'],
#   ['Composition'],
#   ['Composition'],
#   ['Cone'],
#   ['Cone'],
#   ['Cone'],
#   ['Cone'],
#   ['Graph'],
#   ['Graph'],
#   ['Conjugate'],
#   ['Conjugate'],
#   ['Conjugate'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected'],
#   ['Connected', 'Component'],
#   ['Connected', 'Component'],
#   ['Unit', 'Connected'],
#   ['Unit', 'Connected'],
#   ['Difference', 'Cut'],
#   ['Difference', 'Cut'],
#   ['Cut'],
#   ['Cut'],
#   ['Consistent'],
#   ['Consistent'],
#   ['Consistent'],
#   ['Consistent'],
#   ['Consistent'],
#   ['Family'],
#   ['Family'],
#   ['Action'],
#   ['Action'],
#   ['Action'],
#   ['Action'],
#   ['Action'],
#   ['Convex'],
#   ['Convex'],
#   ['Convex'],
#   ['Complete', 'Extension'],
#   ['Complete', 'Extension'],
#   ['Complete', 'Extension'],
#   ['Free'],
#   ['Free'],
#   ['Dimension'],
#   ['Dimension'],
#   ['Cut'],
#   ['Cut'],
#   ['Cycle'],
#   ['Cycle'],
#   ['Index', 'Cycle'],
#   ['Index', 'Cycle'],
#   ['Index', 'Cycle'],
#   ['Cyclic'],
#   ['Cyclic'],
#   ['Cyclic'],
#   ['Cyclic'],
#   ['Complex', 'Cyclic'],
#   ['Complex', 'Cyclic'],
#   ['Cyclic', 'Order'],
#   ['Cyclic', 'Order'],
#   ['Cyclic'],
#   ['Cyclic'],
#   ['Cyclic'],
#   ['Cyclic'],
#   ['Cyclic'],
#   ['Tree'],
#   ['Tree'],
#   ['Decomposition', 'Composition'],
#   ['Decomposition', 'Composition'],
#   ['Decomposition', 'Composition'],
#   ['Decomposition', 'Composition'],
#   ['Decomposition', 'Composition'],
#   ['Decomposition', 'Composition'],
#   ['Decomposition', 'Composition'],
#   ['Zero'],
#   ['Zero'],
#   ['Weak'],
#   ['Weak'],
#   ['Degenerate'],
#   ['Degenerate'],
#   ['Degenerate'],
#   ['Degree'],
#   ['Degree'],
#   ['Degree'],
#   ['Degree'],
#   ['Degree'],
#   ['Degree'],
#   ['Degree'],
#   ['Degree'],
#   ['Degree'],
#   ['Degree'],
#   ['Degree'],
#   ['Density'],
#   ['Density'],
#   ['Density'],
#   ['Density'],
#   ['Density'],
#   ['Density'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Range'],
#   ['Range'],
#   ['Diagonal'],
#   ['Diagonal'],
#   ['Diagram'],
#   ['Diagram'],
#   ['Diagram'],
#   ['Diameter'],
#   ['Diameter'],
#   ['Difference'],
#   ['Difference'],
#   ['Product'],
#   ['Product'],
#   ['Graph'],
#   ['Graph'],
#   ['Dimension'],
#   ['Dimension'],
#   ['Dimension'],
#   ['Dimension'],
#   ['Dimension'],
#   ['Product'],
#   ['Product'],
#   ['Sum'],
#   ['Sum'],
#   ['Sum'],
#   ['Sum'],
#   ['Sum'],
#   ['Root', 'Tree', 'Directed'],
#   ['Root', 'Tree', 'Directed'],
#   ['Root', 'Tree', 'Directed'],
#   ['Discrete'],
#   ['Discrete'],
#   ['Discrete'],
#   ['Discrete'],
#   ['Join'],
#   ['Join'],
#   ['Join'],
#   ['Join'],
#   ['Union', 'Join'],
#   ['Union', 'Join'],
#   ['Sum'],
#   ['Sum'],
#   ['Similar', 'Similarity'],
#   ['Similar', 'Similarity'],
#   ['Distance'],
#   ['Distance'],
#   ['Distance'],
#   ['Distance'],
#   ['Distance'],
#   ['Distance'],
#   ['Distance'],
#   ['Distributive'],
#   ['Distributive'],
#   ['Free'],
#   ['Free'],
#   ['Free'],
#   ['Divisor'],
#   ['Divisor'],
#   ['Dominate', 'Order'],
#   ['Dominate', 'Order'],
#   ['Dominate'],
#   ['Dominate'],
#   ['Dominate'],
#   ['Dominate'],
#   ['Dominate'],
#   ['Dominate'],
#   ['Dominate'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Graph', 'Dual'],
#   ['Graph', 'Dual'],
#   ['Graph', 'Dual'],
#   ['Graph', 'Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Dual'],
#   ['Ideal', 'Edge'],
#   ['Ideal', 'Edge'],
#   ['Ideal', 'Edge'],
#   ['Edge'],
#   ['Edge'],
#   ['Equivalence', 'Involution', 'Dual'],
#   ['Equivalence', 'Involution', 'Dual'],
#   ['Embedding'],
#   ['Embedding'],
#   ['Embedding'],
#   ['Embedding'],
#   ['Embedding'],
#   ['Embedding'],
#   ['Homomorphism'],
#   ['Homomorphism'],
#   ['Expansion'],
#   ['Expansion'],
#   ['Row'],
#   ['Row'],
#   ['Row'],
#   ['Extension'],
#   ['Extension'],
#   ['Extension'],
#   ['Extension'],
#   ['Entropy'],
#   ['Entropy'],
#   ['Face'],
#   ['Face'],
#   ['Factor'],
#   ['Factor'],
#   ['Factor'],
#   ['Factor'],
#   ['Factor'],
#   ['Atom', 'Factor'],
#   ['Atom', 'Factor'],
#   ['Atom', 'Factor'],
#   ['Connected'],
#   ['Connected'],
#   ['Common'],
#   ['Common'],
#   ['Chain'],
#   ['Chain'],
#   ['Orientation'],
#   ['Orientation'],
#   ['Free'],
#   ['Free'],
#   ['Free'],
#   ['Table'],
#   ['Table'],
#   ['Parallel'],
#   ['Parallel'],
#   ['Free'],
#   ['Free'],
#   ['Family'],
#   ['Family'],
#   ['Graph'],
#   ['Graph'],
#   ['Cyclic'],
#   ['Cyclic'],
#   ['Word'],
#   ['Word'],
#   ['Table', 'Content'],
#   ['Table', 'Content'],
#   ['Generated'],
#   ['Generated'],
#   ['Generated'],
#   ['Genus'],
#   ['Genus'],
#   ['Tree', 'Graph'],
#   ['Tree', 'Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Dual'],
#   ['Dual'],
#   ['Height'],
#   ['Height'],
#   ['Height'],
#   ['Height'],
#   ['Free'],
#   ['Free'],
#   ['Homogeneous'],
#   ['Homogeneous'],
#   ['Homogeneous'],
#   ['Homogeneous'],
#   ['Homogeneous'],
#   ['Homogeneous', 'Component'],
#   ['Homogeneous', 'Component'],
#   ['Degree', 'Homogeneous'],
#   ['Degree', 'Homogeneous'],
#   ['Homomorphism'],
#   ['Homomorphism'],
#   ['Homomorphism'],
#   ['Homomorphism'],
#   ['Homomorphism'],
#   ['Complex', 'Homomorphism'],
#   ['Complex', 'Homomorphism'],
#   ['Top'],
#   ['Top'],
#   ['Top'],
#   ['Word'],
#   ['Word'],
#   ['Pair'],
#   ['Pair'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Tree', 'Order'],
#   ['Tree', 'Order'],
#   ['Tree', 'Order'],
#   ['Table'],
#   ['Table'],
#   ['Complex'],
#   ['Complex'],
#   ['Complex'],
#   ['Independent'],
#   ['Independent'],
#   ['Independent'],
#   ['Independent'],
#   ['Independent'],
#   ['Independent'],
#   ['Independent'],
#   ['Independent'],
#   ['Index'],
#   ['Index'],
#   ['Index'],
#   ['Index'],
#   ['Index'],
#   ['Free'],
#   ['Free'],
#   ['Free'],
#   ['Free'],
#   ['Graph'],
#   ['Graph'],
#   ['Family'],
#   ['Family'],
#   ['Section', 'Intersection'],
#   ['Section', 'Intersection'],
#   ['Section', 'Graph', 'Intersection'],
#   ['Section', 'Graph', 'Intersection'],
#   ['Section', 'Graph', 'Intersection'],
#   ['Section', 'Intersection'],
#   ['Section', 'Intersection'],
#   ['Graph'],
#   ['Graph'],
#   ['Inverse'],
#   ['Inverse'],
#   ['Directed', 'Inverse', 'Transitive', 'Complement'],
#   ['Directed', 'Inverse', 'Transitive', 'Complement'],
#   ['Content'],
#   ['Content'],
#   ['Irreducible', 'Reducible'],
#   ['Irreducible', 'Reducible'],
#   ['Irreducible', 'Reducible'],
#   ['Irreducible', 'Reducible'],
#   ['Irreducible', 'Reducible'],
#   ['Irreducible', 'Reducible'],
#   ['Irreducible', 'Reducible'],
#   ['Isomorphism'],
#   ['Isomorphism'],
#   ['Top', 'Strong'],
#   ['Top', 'Strong'],
#   ['Minor'],
#   ['Minor'],
#   ['Join'],
#   ['Join'],
#   ['Join'],
#   ['Join'],
#   ['Join'],
#   ['Join'],
#   ['Length'],
#   ['Length'],
#   ['Length'],
#   ['Length'],
#   ['Length'],
#   ['Graph', 'Product'],
#   ['Graph', 'Product'],
#   ['Limit'],
#   ['Limit'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Graph'],
#   ['Tree'],
#   ['Tree'],
#   ['Extension'],
#   ['Extension'],
#   ['Factor'],
#   ['Factor'],
#   ['Complement'],
#   ['Complement'],
#   ['Complement'],
#   ['Complement'],
#   ['Complement'],
#   ['Complement'],
#   ['Locally Finite'],
#   ['Locally Finite'],
#   ['Reducible'],
#   ['Reducible'],
#   ['Concave'],
#   ['Concave'],
#   ['Edge', 'Loop'],
#   ['Edge', 'Loop'],
#   ['Major', 'Index'],
#   ['Major', 'Index'],
#   ['Major', 'Index'],
#   ['Major', 'Index'],
#   ['Graph'],
#   ['Graph'],
#   ['Diagram'],
#   ['Diagram'],
#   ['Diagram'],
#   ['Sign'],
#   ['Sign'],
#   ['Sign'],
#   ['Sign'],
#   ['Sign'],
#   ['Minor'],
#   ['Minor'],
#   ['Algebra'],
#   ['Algebra'],
#   ['Algebra'],
#   ['Characteristic', 'Character', 'Weight', 'Orthogonal', 'Radius'],
#   ['Characteristic', 'Character', 'Weight', 'Orthogonal', 'Radius'],
#   ['Top'],
#   ['Top'],
#   ['Top'],
#   ['Top'],
#   ['Base', 'Basis'],
#   ['Base', 'Basis'],
#   ['Family'],
#   ['Family'],
#   ['Meet'],
#   ['Meet'],
#   ['Edge'],
#   ['Edge'],
#   ['Minor'],
#   ['Minor'],
#   ['Minor'],
#   ['Root', 'Degree'],
#   ['Root', 'Degree'],
#   ['Graph'],
#   ['Graph'],
#   ['Index'],
#   ['Index'],
#   ['Monotone'],
#   ['Monotone'],
#   ['Monotone'],
#   ['Monotone'],
#   ['Monotone'],
#   ['Monotone'],
#   ['Monotone'],
#   ['Monotone'],
#   ['Monotone'],
#   ['Monotone'],
#   ['Monotone'],
#   ['Isomorphism'],
#   ['Isomorphism'],
#   ['Isomorphism'],
#   ['Isomorphism'],
#   ['Homomorphism'],
#   ['Homomorphism'],
#   ['Multiplicity'],
#   ['Multiplicity'],
#   ['Diagram'],
#   ['Diagram'],
#   ['Row', 'Arrow'],
#   ['Row', 'Arrow'],
#   ['Branch', 'Proper'],
#   ['Branch', 'Proper'],
#   ['Sum'],
#   ['Sum'],
#   ['Singular'],
#   ['Singular'],
#   ['Transitive'],
#   ['Transitive'],
#   ['Trivial'],
#   ['Trivial'],
#   ...])

# %%
mentionned_definienda['mentioned_proofwiki_terms'] = mentioned_terms
mentionned_definienda
# Out:
# /tmp/ipykernel_459341/1074570374.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mentionned_definienda['mentioned_proofwiki_terms'] = mentioned_terms
#                                                  term
# 7                             $(\ep,d)$-reduced graph  \
# 8                             $(\ep,d)$-reduced graph
# 9                             $(\ep,d)$-reduced graph
# 10                                 $(\eps,p)$-regular
# 11                                 $(\eps,p)$-regular
# ...                                               ...
# 3117               {{\it Double pants decomposition}}
# 3118  {{\it Lagrangian plane of pants decomposition}}
# 3119  {{\it Lagrangian plane of pants decomposition}}
# 3122                      {{\it Pants decomposition}}
# 3123                      {{\it Pants decomposition}}
#
#                                                     def
# 7     \label{def:reduced}\nGiven a 2-colored graph $...  \
# 8     \label{def:reduced}\nGiven a graph $G$, an ini...
# 9     \label{def:reduced}\nGiven an $X,Y$-bipartite ...
# 10    [$(\eps,p)$-regular pair]\n\t\label{def:ep-reg...
# 11    \label{def:eps_p_regular}\nA bipartite graph ~...
# ...                                                 ...
# 3117  A {\it double pants decomposition} $DP=(P_a,P_...
# 3118  Let $P=\{ c_1,\dots,c_{3g-3+2n}\}$ be a pants ...
# 3119  Let $P=\{ c_1,\dots,c_{3g-3}\}$ be a pants dec...
# 3122  A {\it pants decomposition} of $S$ is a set of...
# 3123  A {\it pants decomposition} $P$ of $S$ is a sy...
#
#                                       file_name       extraction_rule
# 7        1611.05423#revised-infMono-8-14-18.tex          definition[]  \
# 8       1409.1874#2colorCycles_arXiv_090116.tex          definition[]
# 9     1806.05119#2colorbipartitePath_061318.tex          definition[]
# 10                       1302.2248#erdos100.tex  definition + \emph{}
# 11                  0908.3778#ESRG-extended.tex  definition + \emph{}
# ...                                         ...                   ...
# 3117                    1005.0073#pants-new.tex          definition[]
# 3118                     1102.4861#length12.tex          definition[]
# 3119                    1005.0073#pants-new.tex          definition[]
# 3122                     1102.4861#length12.tex          definition[]
# 3123                    1005.0073#pants-new.tex          definition[]
#
#                                          plain_text_def
# 7     \nGiven a 2-colored graph G and a partition {V...  \
# 8     \nGiven a graph G, an initial partition {Q_1, ...
# 9     \nGiven an X,Y-bipartite graph G and partition...
# 10    [(,p)-regular pair]\n\t\n\tLet >0, let p∈(0,1]...
# 11    \nA bipartite graph  B = (V_1 ∪ V_2, E)  is ca...
# ...                                                 ...
# 3117  A double pants decomposition DP=(P_a,P_b) is a...
# 3118  Let P={ c_1,…,c_3g-3+2n} be a pants decomposit...
# 3119  Let P={ c_1,…,c_3g-3} be a pants decomposition...
# 3122  A pants decomposition of S is a set of (non-or...
# 3123  A pants decomposition P of S is a system of no...
#
#                               plain_text_term     mentioned_proofwiki_terms
# 7                          (,d)-reduced graph                       [Graph]
# 8                          (,d)-reduced graph                       [Graph]
# 9                          (,d)-reduced graph                       [Graph]
# 10                               (,p)-regular                     [Regular]
# 11                               (,p)-regular                     [Regular]
# ...                                       ...                           ...
# 3117               Double pants decomposition  [Decomposition, Composition]
# 3118  Lagrangian plane of pants decomposition  [Decomposition, Composition]
# 3119  Lagrangian plane of pants decomposition  [Decomposition, Composition]
# 3122                      Pants decomposition  [Decomposition, Composition]
# 3123                      Pants decomposition  [Decomposition, Composition]
#
# [1530 rows x 7 columns]

# %%
mentionned_definienda['mentioned_proofwiki_terms'].value_counts().to_csv("mentioned_proofwiki_terms_value_counts.csv")

# %%
mentionned_definienda.to_csv("arXiv_terms_including_proofwiki_terms.csv", index=False)

# %% [markdown]
# ## Can text similarity help us to link arXiv definitions to proofwiki entities ?
